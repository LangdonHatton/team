# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('titles.csv.csv')

# %%
df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 685.7+ KB

# %%
df['age_certification']=df['age_certification'].fillna(df['age_certification'].mode()[0])
df['seasons'].replace(np.nan, 'No Data', inplace=True)
df['imdb_score'].replace(np.nan, 'No Data', inplace=True)
df['imdb_votes'].replace(np.nan, 'No Data', inplace=True)
df['seasons'].replace(np.nan, 'No Data', inplace=True)
df['runtime'].replace(np.nan, 'No Data', inplace=True)

# %%
df.sample(10)
# Out:
#              id                             title   type  \
# 300    tm141390                   Friday the 13th  MOVIE
# 5763  tm1160938  Adam by Eve: A Live in Animation  MOVIE
# 158     ts21693                    Sister, Sister   SHOW
# 5748  tm1111559                  Grumpy Christmas  MOVIE
# 1221   tm136483                          The DUFF  MOVIE
# 4198   tm852662                            Ultras  MOVIE
# 1831    ts78430                        Collateral   SHOW
# 3749   tm461159                           Trouble  MOVIE
# 1510   tm193388                            Dhanak  MOVIE
# 4728   ts356887           How To Build a Sex Room   SHOW
#
#                                             description  release_year  \
# 300   A group of young adults visit a boarded up cam...          2009
# 5763  Anime, live action and music by cutting-edge a...          2022
# 158   Twins Tia Landry and Tamera Campbell were sepa...          1994
# 5748  Bitter, grumpy patriarch Don Servando and his ...          2021
# 1221  Bianca's universe turns upside down when she l...          2015
# 4198  An aging soccer fanatic faces down the reality...          2020
# 1831  When a pizza delivery driver is shot dead in s...          2018
# 3749  A pampered dog named Trouble must learn to liv...          2019
# 1510  Orphaned siblings Pari and Chotu embark on a j...          2015
# 4728  Couples looking for more spice in the bedroom ...          2022
#
#      age_certification  runtime  \
# 300                  R       97
# 5763             PG-13       58
# 158              TV-PG       22
# 5748             TV-MA       87
# 1221             PG-13      101
# 4198             TV-MA      109
# 1831             TV-MA       57
# 3749             TV-MA       88
# 1510             TV-MA      106
# 4728             TV-MA       42
#
#                                                  genres production_countries  \
# 300                              ['horror', 'thriller']               ['US']
# 5763                    ['drama', 'animation', 'music']               ['JP']
# 158                       ['comedy', 'drama', 'family']               ['US']
# 5748                                         ['comedy']               ['MX']
# 1221                              ['comedy', 'romance']               ['US']
# 4198                                          ['drama']               ['IT']
# 1831                     ['thriller', 'drama', 'crime']               ['GB']
# 3749  ['action', 'family', 'comedy', 'music', 'anima...               ['CA']
# 1510                                ['drama', 'comedy']               ['IN']
# 4728                                        ['reality']               ['US']
#
#       seasons     imdb_id imdb_score imdb_votes  tmdb_popularity  tmdb_score
# 300   No Data   tt0758746        5.5   106970.0           45.551         5.8
# 5763  No Data  tt18274178        6.1      378.0            3.828         6.3
# 158       6.0   tt0108927        6.2    12657.0           21.489         7.5
# 5748  No Data  tt15565724        4.4      355.0           32.532         7.6
# 1221  No Data   tt1666801        6.4    93675.0           26.748         6.8
# 4198  No Data  tt10937434        6.2     4892.0            6.740         6.1
# 1831      1.0   tt6729080        6.7    17774.0           23.364         6.4
# 3749  No Data   tt6772524        5.8     3281.0           17.173         6.7
# 1510  No Data   tt4088588        7.9     3893.0            2.918         7.5
# 4728      1.0  tt21030224        5.3      181.0            8.976         8.1

# %%
# scatter plot for number of seasons compared to runtime

# %%
df['runtime'] = pd.to_numeric(df['runtime'], errors='coerce')
df['seasons'] = pd.to_numeric(df['seasons'], errors='coerce')
df['runtime'] = pd.to_numeric(df['runtime'].replace('[^0-9\.]', '', regex=True), errors='coerce')
df['seasons'] = pd.to_numeric(df['seasons'].replace('[^0-9\.]', '', regex=True), errors='coerce')
df.dropna(subset=['runtime', 'seasons'], inplace=True)

# %%
plt.scatter(df['runtime'], df['seasons'])


plt.xlabel('Runtime')
plt.ylabel('Seasons')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.hist(df['runtime'], bins=20)


plt.xlabel('Runtime (minutes)')
plt.ylabel('Number of shows')
plt.title('Distribution of Runtime')
# Out:
# Text(0.5, 1.0, 'Distribution of Runtime')

# %%
plt.hist(df['seasons'], bins=20)


plt.xlabel('Runtime (minutes)')
plt.ylabel('Number of shows')
plt.title('Distribution of Runtime')
# Out:
# Text(0.5, 1.0, 'Distribution of Runtime')

# %%
df.sample(10)
# Out:
#             id                          title  type  \
# 4452  ts257243                 Voices of Fire  SHOW
# 3669   ts89231                   You vs. Wild  SHOW
# 2097   ts75620                          Black  SHOW
# 5204  ts297675                    Sexy Beasts  SHOW
# 3402  ts192440  Garth Brooks: The Road I'm On  SHOW
# 3176   ts84661                         Cursed  SHOW
# 1967   ts81542                     The Hollow  SHOW
# 2390   ts89067               Love and Fortune  SHOW
# 2309   ts56636                  My Sassy Girl  SHOW
# 2654   ts86279            Nailed It! Holiday!  SHOW
#
#                                             description  release_year  \
# 4452  Pharrell Williams's hometown community leaders...          2020
# 3669  In this interactive series, you'll make key de...          2019
# 2097  A Grim Reaper, a detective and a woman who for...          2017
# 5204  Hoping to say goodbye to superficial dating, r...          2021
# 3402  A look at the life and career of Garth Brooks ...          2019
# 3176  In this fresh take on the Arthurian legend, te...          2020
# 1967  Three teens join forces to find a way home aft...          2018
# 2390  Wako Taira is 31-years-old. She works part-tim...          2018
# 2309  Set in the Joseon Dynasty period, a romance ta...          2017
# 2654  It's the "Nailed It!" holiday special you've b...          2018
#
#      age_certification  runtime  \
# 4452             TV-PG       37
# 3669             TV-PG       19
# 2097             TV-MA       78
# 5204             TV-14       23
# 3402             TV-PG       86
# 3176             TV-MA       55
# 1967             TV-Y7       24
# 2390             TV-MA       58
# 2309             TV-14       44
# 2654             TV-PG       33
#
#                                                  genres production_countries  \
# 4452                               ['music', 'reality']               ['US']
# 3669                              ['reality', 'action']               ['US']
# 2097  ['scifi', 'drama', 'action', 'thriller', 'horr...               ['KR']
# 5204                             ['reality', 'romance']                   []
# 3402                       ['documentation', 'reality']               ['US']
# 3176            ['action', 'scifi', 'fantasy', 'drama']               ['US']
# 1967  ['comedy', 'scifi', 'animation', 'drama', 'fam...               ['CA']
# 2390                               ['drama', 'romance']               ['JP']
# 2309                              ['comedy', 'romance']               ['KR']
# 2654                                        ['reality']               ['US']
#
#       seasons     imdb_id imdb_score imdb_votes  tmdb_popularity  tmdb_score
# 4452      1.0  tt13329282        6.8      388.0            1.137         8.0
# 3669      2.0  tt10044952        6.6     2606.0            3.864         6.7
# 2097      2.0   tt7298976        7.9     3891.0           39.083         8.0
# 5204      2.0  tt14916746        4.6     1133.0           36.721         5.9
# 3402      1.0  tt10095402        7.4      287.0            0.699        10.0
# 3176      1.0   tt8210856        5.8    29864.0           30.279         7.4
# 1967      2.0   tt2372708        7.1     4266.0           10.299         7.1
# 2390      1.0   tt8649316        7.3      555.0            4.984         6.5
# 2309      1.0   tt6175760        6.8      597.0            6.648         7.3
# 2654      2.0   tt8760264        7.7     1098.0            3.101         8.0

# %%
# bar plot of seasons and run time
bar=df['seasons'].value_counts()

# %%
bar[:10]
# Out:
# 1.0     1221
# 2.0      389
# 3.0      187
# 4.0      120
# 5.0       79
# 6.0       36
# 7.0       18
# 8.0       11
# 9.0        9
# 11.0       8
# 10.0       6
# Name: seasons, dtype: int64

# %%
bar[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        release_year      runtime      seasons  tmdb_popularity   tmdb_score
# count   2106.000000  2106.000000  2106.000000      2077.000000  1990.000000
# mean    2017.387939    38.978158     2.162868        26.756694     7.480413
# std        5.381505    17.626354     2.689041        87.589718     1.099177
# min     1945.000000     0.000000     1.000000         0.600000     0.500000
# 25%     2017.000000    25.000000     1.000000         3.341000     7.000000
# 50%     2019.000000    41.000000     1.000000         8.413000     7.500000
# 75%     2020.000000    49.000000     2.000000        20.099000     8.100000
# max     2022.000000   190.000000    42.000000      2226.231000    10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2106 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2106 non-null   object
#  1   title                 2106 non-null   object
#  2   type                  2106 non-null   object
#  3   description           2097 non-null   object
#  4   release_year          2106 non-null   int64
#  5   age_certification     2106 non-null   object
#  6   runtime               2106 non-null   int64
#  7   genres                2106 non-null   object
#  8   production_countries  2106 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               1965 non-null   object
#  11  imdb_score            2106 non-null   object
#  12  imdb_votes            2106 non-null   object
#  13  tmdb_popularity       2077 non-null   float64
#  14  tmdb_score            1990 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 263.2+ KB

# %%
df.head(1)
# Out:
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
#   age_certification  runtime             genres production_countries  seasons  \
# 0             TV-MA       51  ['documentation']               ['US']      1.0
#
#   imdb_id imdb_score imdb_votes  tmdb_popularity  tmdb_score
# 0     NaN    No Data    No Data              0.6         NaN

# %%
new_df = df.copy()



new_df = new_df[new_df['imdb_score'] != 'No Data']
new_df['imdb_score'] = new_df['imdb_score'].astype(float)

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score  tmdb_popularity  \
# count   2106.000000  2106.000000  2106.000000  1939.000000      2077.000000
# mean    2017.387939    38.978158     2.162868     6.977927        26.756694
# std        5.381505    17.626354     2.689041     1.077401        87.589718
# min     1945.000000     0.000000     1.000000     2.000000         0.600000
# 25%     2017.000000    25.000000     1.000000     6.400000         3.341000
# 50%     2019.000000    41.000000     1.000000     7.100000         8.413000
# 75%     2020.000000    49.000000     2.000000     7.700000        20.099000
# max     2022.000000   190.000000    42.000000     9.600000      2226.231000
#
#         tmdb_score
# count  1990.000000
# mean      7.480413
# std       1.099177
# min       0.500000
# 25%       7.000000
# 50%       7.500000
# 75%       8.100000
# max      10.000000

# %%
new_df2 = df.copy()
new_df2 = new_df2[new_df2['imdb_votes'] != 'No Data'].copy()
new_df2['imdb_votes'] = new_df2['imdb_votes'].astype(float)

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score  tmdb_popularity  \
# count   2106.000000  2106.000000  2106.000000  1939.000000      2077.000000
# mean    2017.387939    38.978158     2.162868     6.977927        26.756694
# std        5.381505    17.626354     2.689041     1.077401        87.589718
# min     1945.000000     0.000000     1.000000     2.000000         0.600000
# 25%     2017.000000    25.000000     1.000000     6.400000         3.341000
# 50%     2019.000000    41.000000     1.000000     7.100000         8.413000
# 75%     2020.000000    49.000000     2.000000     7.700000        20.099000
# max     2022.000000   190.000000    42.000000     9.600000      2226.231000
#
#         tmdb_score
# count  1990.000000
# mean      7.480413
# std       1.099177
# min       0.500000
# 25%       7.000000
# 50%       7.500000
# 75%       8.100000
# max      10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2106 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2106 non-null   object
#  1   title                 2106 non-null   object
#  2   type                  2106 non-null   object
#  3   description           2097 non-null   object
#  4   release_year          2106 non-null   int64
#  5   age_certification     2106 non-null   object
#  6   runtime               2106 non-null   int64
#  7   genres                2106 non-null   object
#  8   production_countries  2106 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               1965 non-null   object
#  11  imdb_score            1939 non-null   float64
#  12  imdb_votes            2106 non-null   object
#  13  tmdb_popularity       2077 non-null   float64
#  14  tmdb_score            1990 non-null   float64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 263.2+ KB

# %%
df.head(20)
# Out:
#            id                                title  type  \
# 0    ts300399  Five Came Back: The Reference Films  SHOW
# 5     ts22164         Monty Python's Flying Circus  SHOW
# 26    ts45948     Monty Python's Fliegender Zirkus  SHOW
# 35    ts20681                             Seinfeld  SHOW
# 44    ts22082                         Knight Rider  SHOW
# 45    ts21715                     Thomas & Friends  SHOW
# 46    ts20678                    Saved by the Bell  SHOW
# 48    ts25028                     Wheel of Fortune  SHOW
# 53    ts23753                            Major Dad  SHOW
# 55      ts987                         Danger Mouse  SHOW
# 59     ts2760                          Fireman Sam  SHOW
# 83    ts63001                            High Risk  SHOW
# 91    ts20981                             Survivor  SHOW
# 93    ts22176                        Stargate SG-1  SHOW
# 95    ts21223                              Pokémon  SHOW
# 100   ts20339                            One Piece  SHOW
# 101    ts5145                        The Challenge  SHOW
# 103   ts34435                         Cowboy Bebop  SHOW
# 107   ts20983              Neon Genesis Evangelion  SHOW
# 110   ts21567                        Gilmore Girls  SHOW
#
#                                            description  release_year  \
# 0    This collection includes 12 World War II-era p...          1945
# 5    A British sketch comedy series with the shows ...          1969
# 26   Monty Python's Fliegender Zirkus consisted of ...          1972
# 35   A stand-up comedian and his three offbeat frie...          1989
# 44   Michael Long, an undercover police officer, is...          1982
# 45   Thomas & Friends is a British children's telev...          1984
# 46   Lovable schemer Zack Morris leads his pals on ...          1989
# 48   This game show sees contestants solve word puz...          1983
# 53   Major Dad is an American sitcom created by Ric...          1989
# 55   Danger Mouse, the world's greatest secret agen...          1981
# 59   Follow the adventures of fireman Sam and his c...          1987
# 83   High Risk is a program aired by the CBS televi...          1988
# 91   A reality show contest where sixteen or more c...          2000
# 93   The story of Stargate SG-1 begins about a year...          1997
# 95   Join Ash accompanied by his partner Pikachu, a...          1997
# 100  Years ago, the fearsome Pirate King, Gol D. Ro...          1999
# 101  Each Challenge pits numerous cast members from...          1998
# 103  In 2071, roughly fifty years after an accident...          1998
# 107  At the turn of the century, the Angels returne...          1995
# 110  Set in the charming town of Stars Hollow, Conn...          2000
#
#     age_certification  runtime  \
# 0               TV-MA       51
# 5               TV-14       30
# 26              TV-MA       43
# 35              TV-PG       24
# 44              TV-PG       51
# 45               TV-Y       10
# 46               TV-G       23
# 48               TV-G       26
# 53              TV-PG       24
# 55               TV-Y       14
# 59               TV-Y       10
# 83              TV-PG       50
# 91              TV-PG       48
# 93              TV-PG       44
# 95              TV-Y7       22
# 100             TV-14       23
# 101             TV-14       40
# 103             TV-14       25
# 107             TV-14       24
# 110             TV-14       46
#
#                                                 genres production_countries  \
# 0                                    ['documentation']               ['US']
# 5                               ['comedy', 'european']               ['GB']
# 26                                          ['comedy']                   []
# 35                                          ['comedy']               ['US']
# 44               ['scifi', 'action', 'crime', 'drama']               ['US']
# 45   ['animation', 'family', 'comedy', 'fantasy', '...               ['GB']
# 46                     ['family', 'comedy', 'romance']               ['US']
# 48                                          ['family']               ['US']
# 53                                ['comedy', 'family']               ['US']
# 55   ['animation', 'comedy', 'family', 'scifi', 'eu...               ['GB']
# 59   ['animation', 'comedy', 'family', 'crime', 'eu...               ['GB']
# 83                                          ['comedy']               ['US']
# 91                                         ['reality']               ['US']
# 93                        ['scifi', 'drama', 'action']         ['CA', 'US']
# 95   ['action', 'scifi', 'animation', 'comedy', 'fa...               ['JP']
# 100  ['animation', 'action', 'comedy', 'drama', 'fa...               ['JP']
# 101            ['reality', 'comedy', 'drama', 'scifi']               ['US']
# 103  ['animation', 'action', 'scifi', 'western', 'c...               ['JP']
# 107  ['drama', 'scifi', 'animation', 'action', 'fan...               ['JP']
# 110                                ['comedy', 'drama']               ['US']
#
#      seasons     imdb_id  imdb_score imdb_votes  tmdb_popularity  tmdb_score
# 0        1.0         NaN         NaN    No Data            0.600         NaN
# 5        4.0   tt0063929         8.8    73424.0           17.617       8.306
# 26       1.0   tt0202477         8.1     2151.0            1.487       7.000
# 35       9.0   tt0098904         8.9   308824.0          130.213       8.301
# 44       4.0   tt0083437         6.9    34115.0           50.267       7.500
# 45      24.0   tt0086815         6.5     5104.0           42.196       6.500
# 46       5.0   tt0096694         7.1    35034.0           19.855       8.000
# 48      39.0   tt0072584         6.7     3145.0            5.935       6.800
# 53       4.0   tt0096643         6.5     2922.0            9.849       6.500
# 55      10.0   tt0081848         7.4     3545.0            8.550       7.500
# 59      13.0   tt0329829         6.1     1785.0           37.647       7.200
# 83       1.0   tt5944220         3.8        6.0            1.400         NaN
# 91      42.0   tt0239195         7.4    24687.0           54.190       7.400
# 93      10.0   tt0118480         8.4    90196.0           88.851       8.300
# 95      25.0  tt14053732         7.4      198.0          115.356       7.633
# 100     21.0   tt0388629         8.8   117129.0          143.457       8.764
# 101     37.0   tt6274074         7.8     3362.0           18.075       7.700
# 103      1.0   tt0213338         8.9   115448.0           35.402       8.522
# 107      1.0   tt0112159         8.5    66629.0           49.270       8.637
# 110      8.0   tt0238784         8.2   121462.0           58.578       7.827

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2106 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2106 non-null   object
#  1   title                 2106 non-null   object
#  2   type                  2106 non-null   object
#  3   description           2097 non-null   object
#  4   release_year          2106 non-null   int64
#  5   age_certification     2106 non-null   object
#  6   runtime               2106 non-null   int64
#  7   genres                2106 non-null   object
#  8   production_countries  2106 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               1965 non-null   object
#  11  imdb_score            1939 non-null   float64
#  12  imdb_votes            2106 non-null   object
#  13  tmdb_popularity       2077 non-null   float64
#  14  tmdb_score            1990 non-null   float64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 263.2+ KB

# %%
new_df2.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   1939.000000  1939.000000  1939.000000  1939.000000  1.939000e+03
# mean    2017.332646    38.765859     2.232078     6.977927  1.733155e+04
# std        5.179166    17.207135     2.769952     1.077401  7.208902e+04
# min     1969.000000     0.000000     1.000000     2.000000  5.000000e+00
# 25%     2016.000000    25.000000     1.000000     6.400000  4.580000e+02
# 50%     2019.000000    41.000000     1.000000     7.100000  1.766000e+03
# 75%     2020.000000    49.000000     2.500000     7.700000  7.203500e+03
# max     2022.000000   178.000000    42.000000     9.600000  1.775990e+06
#
#        tmdb_popularity   tmdb_score
# count      1914.000000  1860.000000
# mean         27.970410     7.472083
# std          90.343132     1.067492
# min           0.600000     1.000000
# 25%           3.580000     6.900000
# 50%           8.716500     7.500000
# 75%          21.132750     8.100000
# max        2226.231000    10.000000

# %%
df.head(1)
# Out:
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
#   age_certification  runtime             genres production_countries  seasons  \
# 0             TV-MA       51  ['documentation']               ['US']      1.0
#
#   imdb_id  imdb_score imdb_votes  tmdb_popularity  tmdb_score
# 0     NaN         NaN    No Data              0.6         NaN

# %%
num_unique = df['id'].nunique()
print(f"The  column has {num_unique} unique values.")
# Out:
# The  column has 2106 unique values.

# %%
num_unique = df['type'].nunique()
print(f"The  column has {num_unique} unique values.")
# Out:
# The  column has 1 unique values.

# %%
num_unique = df['description'].nunique()
print(f"The  column has {num_unique} unique values.")
# Out:
# The  column has 2096 unique values.

# %%
num_unique = df['type'].nunique()
print(f"The  column has {num_unique} unique values.")
# Out:
# The  column has 1 unique values.

# %%
num_unique = df['age_certification'].nunique()
print(f"The  column has {num_unique} unique values.")
# Out:
# The  column has 6 unique values.

# %%
num_unique = df['genres'].nunique()
print(f"The  column has {num_unique} unique values.")
# Out:
# The  column has 846 unique values.

# %%
num_unique = df['production_countries'].nunique()
print(f"The  column has {num_unique} unique values.")
# Out:
# The  column has 114 unique values.

# %%
counts = df['type'].value_counts()

# Print the frequency and proportion percentage for each value
for value, count in counts.items():
    freq = count
    prop = count / len(new_df2) * 100
    print(f"{value}: {freq} ({prop:.2f}%)")
# Out:
# SHOW: 2106 (108.61%)

# %%
object_cols = ['age_certification','type']
df_subset = df[object_cols]
for col in df_subset:
    freq_count = df[col].value_counts()
    prop_percent = freq_count / len(df) * 100
    
  
    table = pd.DataFrame({
        'Category': freq_count.index,
        'Frequency': freq_count.values,
        'Proportion (%)': prop_percent.values.round(2)})
    
    print(f"Table 3: Proportions for {col} (n={len(df)})\n")
    print(table.to_string(index=False))
    print('\n')
# Out:
# Table 3: Proportions for age_certification (n=2106)
#
# Category  Frequency  Proportion (%)
#    TV-MA       1138           54.04
#    TV-14        474           22.51
#    TV-PG        188            8.93
#    TV-Y7        120            5.70
#     TV-Y        107            5.08
#     TV-G         79            3.75
#
#
# Table 3: Proportions for type (n=2106)
#
# Category  Frequency  Proportion (%)
#     SHOW       2106           100.0

# %%
print(df['type'].unique())
# Out:
# ['SHOW']

# %%
df['type'] = df['type'].str.strip().str.lower()


print(df['type'].unique())
# Out:
# ['show']

# %%
print(df['type'].value_counts())
# Out:
# show    2106
# Name: type, dtype: int64

# %%
df=pd.read_csv('titles.csv.csv')

# %%
print(df['type'].value_counts())
# Out:
# MOVIE    3744
# SHOW     2106
# Name: type, dtype: int64

# %%
# THis is for the proportions

# %%
object_cols = ['age_certification','type']
df_subset = df[object_cols]
for col in df_subset:
    freq_count = df[col].value_counts()
    prop_percent = freq_count / len(df) * 100
    
  
    table = pd.DataFrame({
        'Category': freq_count.index,
        'Frequency': freq_count.values,
        'Proportion (%)': prop_percent.values.round(2)})
    
    print(f"Table 3: Proportions for {col} (n={len(df)})\n")
    print(table.to_string(index=False))
    print('\n')
# Out:
# Table 3: Proportions for age_certification (n=5850)
#
# Category  Frequency  Proportion (%)
#    TV-MA        883           15.09
#        R        556            9.50
#    TV-14        474            8.10
#    PG-13        451            7.71
#       PG        233            3.98
#    TV-PG        188            3.21
#        G        124            2.12
#    TV-Y7        120            2.05
#     TV-Y        107            1.83
#     TV-G         79            1.35
#    NC-17         16            0.27
#
#
# Table 3: Proportions for type (n=5850)
#
# Category  Frequency  Proportion (%)
#    MOVIE       3744            64.0
#     SHOW       2106            36.0

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5850.000000  5850.000000  2106.000000  5368.000000  5.352000e+03
# mean    2016.417094    76.888889     2.162868     6.510861  2.343938e+04
# std        6.937726    39.002509     2.689041     1.163826  9.582047e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2016.000000    44.000000     1.000000     5.800000  5.167500e+02
# 50%     2018.000000    83.000000     1.000000     6.600000  2.233500e+03
# 75%     2020.000000   104.000000     2.000000     7.300000  9.494000e+03
# max     2022.000000   240.000000    42.000000     9.600000  2.294231e+06
#
#        tmdb_popularity   tmdb_score
# count      5759.000000  5539.000000
# mean         22.637925     6.829175
# std          81.680263     1.170391
# min           0.009442     0.500000
# 25%           2.728500     6.100000
# 50%           6.821000     6.900000
# 75%          16.590000     7.537500
# max        2274.044000    10.000000

# %%
print(df['age_certification'].value_counts())
# Out:
# TV-MA    883
# R        556
# TV-14    474
# PG-13    451
# PG       233
# TV-PG    188
# G        124
# TV-Y7    120
# TV-Y     107
# TV-G      79
# NC-17     16
# Name: age_certification, dtype: int64

# %%
df.corr()
# Out:
#                  release_year   runtime   seasons  imdb_score  imdb_votes  \
# release_year         1.000000 -0.173551 -0.504407   -0.129380   -0.208815
# runtime             -0.173551  1.000000 -0.139642   -0.148068    0.139760
# seasons             -0.504407 -0.139642  1.000000    0.106806    0.206079
# imdb_score          -0.129380 -0.148068  0.106806    1.000000    0.190661
# imdb_votes          -0.208815  0.139760  0.206079    0.190661    1.000000
# tmdb_popularity      0.043244  0.002545  0.168051    0.017675    0.209763
# tmdb_score           0.032073 -0.277454  0.044023    0.570754    0.112960
#
#                  tmdb_popularity  tmdb_score
# release_year            0.043244    0.032073
# runtime                 0.002545   -0.277454
# seasons                 0.168051    0.044023
# imdb_score              0.017675    0.570754
# imdb_votes              0.209763    0.112960
# tmdb_popularity         1.000000    0.071894
# tmdb_score              0.071894    1.000000

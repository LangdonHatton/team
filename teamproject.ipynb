# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('titles.csv.csv')

# %%
df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2106 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2106 non-null   object
#  1   title                 2106 non-null   object
#  2   type                  2106 non-null   object
#  3   description           2097 non-null   object
#  4   release_year          2106 non-null   int64
#  5   age_certification     2106 non-null   object
#  6   runtime               2106 non-null   int64
#  7   genres                2106 non-null   object
#  8   production_countries  2106 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               1965 non-null   object
#  11  imdb_score            2106 non-null   object
#  12  imdb_votes            2106 non-null   object
#  13  tmdb_popularity       2077 non-null   float64
#  14  tmdb_score            1990 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 263.2+ KB

# %%
df['age_certification']=df['age_certification'].fillna(df['age_certification'].mode()[0])
df['seasons'].replace(np.nan, 'No Data', inplace=True)
df['imdb_score'].replace(np.nan, 'No Data', inplace=True)
df['imdb_votes'].replace(np.nan, 'No Data', inplace=True)
df['seasons'].replace(np.nan, 'No Data', inplace=True)
df['runtime'].replace(np.nan, 'No Data', inplace=True)

# %%
df.sample(10)
# Out:
#             id                                title   type  \
# 3541  tm855535                            The Hater  MOVIE
# 131   tm187791                  In the Line of Fire  MOVIE
# 1344   ts58068  Inside the World's Toughest Prisons   SHOW
# 770    tm48239                   Ek Main Aur Ekk Tu  MOVIE
# 2300  tm444469                                Eerie  MOVIE
# 5004  ts273485                           Baki Hanma   SHOW
# 2548   ts81596                          Black Crows   SHOW
# 3454  tm835486            Jenny Slate: Stage Fright  MOVIE
# 1465  ts127430                StoryBots Super Songs   SHOW
# 1625   ts81027                                Spark   SHOW
#
#                                             description  release_year  \
# 3541  A duplicitous young man finds success in the d...          2020
# 131   Veteran Secret Service agent Frank Horrigan is...          1993
# 1344  Crime journalist Paul Connolly goes behind the...          2016
# 770   Rahul and Riana meet each other for the first ...          2012
# 2300  The unexpected and gruesome death of a student...          2018
# 5004  To gain the skills he needs to surpass his pow...          2021
# 2548  This drama portrays women and kids living unde...          2017
# 3454  Jenny Slate's debut stand up-comedy special bl...          2019
# 1465  Based on the award-winning educational apps, "...          2016
# 1625  'Spark' is a mini music drama like a night con...          2016
#
#      age_certification  runtime  \
# 3541             TV-MA      135
# 131                  R      128
# 1344             TV-MA       48
# 770                 PG      110
# 2300             TV-MA      101
# 5004             TV-MA       25
# 2548             TV-MA       33
# 3454             TV-MA       66
# 1465              TV-Y       21
# 1625             TV-14       14
#
#                                                  genres production_countries  \
# 3541                  ['drama', 'thriller', 'european']               ['PL']
# 131            ['drama', 'thriller', 'crime', 'action']               ['US']
# 1344                         ['crime', 'documentation']               ['GB']
# 770                      ['drama', 'romance', 'comedy']               ['IN']
# 2300           ['horror', 'crime', 'thriller', 'drama']         ['PH', 'SG']
# 5004  ['animation', 'action', 'drama', 'sport', 'thr...               ['JP']
# 2548                       ['drama', 'war', 'thriller']   ['SA', 'SY', 'AE']
# 3454                              ['comedy', 'reality']               ['US']
# 1465                            ['animation', 'family']               ['US']
# 1625                                          ['drama']               ['KR']
#
#       seasons     imdb_id imdb_score imdb_votes  tmdb_popularity  tmdb_score
# 3541  No Data         NaN    No Data    No Data           12.908       6.900
# 131   No Data   tt0107206        7.2   102916.0           19.800       6.973
# 1344      5.0   tt6322264        7.1     2747.0            5.099       7.500
# 770   No Data   tt1703958        5.7     6820.0            4.062       5.600
# 2300  No Data   tt8723216        4.6     2324.0            6.895       5.400
# 5004      2.0  tt13357140        6.6     1685.0          211.093       8.049
# 2548      1.0   tt7356518        5.3      308.0            4.802       8.000
# 3454  No Data  tt10971520        5.8     1291.0            3.462       5.900
# 1465      1.0   tt6163070        8.7      170.0            0.600       9.000
# 1625      5.0   tt6409112        7.0       63.0            1.400         NaN

# %%
# scatter plot for number of seasons compared to runtime

# %%
df['runtime'] = pd.to_numeric(df['runtime'], errors='coerce')
df['seasons'] = pd.to_numeric(df['seasons'], errors='coerce')
df['runtime'] = pd.to_numeric(df['runtime'].replace('[^0-9\.]', '', regex=True), errors='coerce')
df['seasons'] = pd.to_numeric(df['seasons'].replace('[^0-9\.]', '', regex=True), errors='coerce')
df.dropna(subset=['runtime', 'seasons'], inplace=True)

# %%
plt.scatter(df['runtime'], df['seasons'])


plt.xlabel('Runtime')
plt.ylabel('Seasons')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.hist(df['runtime'], bins=20)


plt.xlabel('Runtime (minutes)')
plt.ylabel('Number of shows')
plt.title('Distribution of Runtime')
# Out:
# Text(0.5, 1.0, 'Distribution of Runtime')

# %%
plt.hist(df['seasons'], bins=20)


plt.xlabel('Runtime (minutes)')
plt.ylabel('Number of shows')
plt.title('Distribution of Runtime')
# Out:
# Text(0.5, 1.0, 'Distribution of Runtime')

# %%
df.sample(10)
# Out:
#             id                                        title  type  \
# 5458   ts14520                                  Action Pack  SHOW
# 2246   ts82298                                Familiar Wife  SHOW
# 2449   ts79330                           Girls Incarcerated  SHOW
# 4929  ts271413  Night Stalker: The Hunt for a Serial Killer  SHOW
# 837     ts1639                                The Blacklist  SHOW
# 5667  ts330422                                Team Zenko Go  SHOW
# 53     ts23753                                    Major Dad  SHOW
# 673    ts27468                    Transformers: Rescue Bots  SHOW
# 2110   ts75981                   The Royal House of Windsor  SHOW
# 348    ts21421                                       Pocoyo  SHOW
#
#                                             description  release_year  \
# 5458  The heroic kids of the Action Academy take on ...          2022
# 2246  After receiving a bizarre chance to go back in...          2018
# 2449  An eight-part documentary series that goes beh...          2018
# 4929  Beneath the sunlit glamour of 1985 L.A. lurks ...          2021
# 837   Raymond "Red" Reddington, one of the FBI's mos...          2013
# 5667  Every good deed is one for this team of kids. ...          2022
# 53    Major Dad is an American sitcom created by Ric...          1989
# 673   A team of specialized Autobots not quite ready...          2012
# 2110  Drawing on newly available evidence, this epic...          2017
# 348   Pocoyo is a Spanish pre-school animated televi...          2005
#
#      age_certification  runtime  \
# 5458              TV-Y       28
# 2246             TV-MA       62
# 2449             TV-MA       43
# 4929             TV-MA       47
# 837              TV-14       43
# 5667              TV-Y       20
# 53               TV-PG       24
# 673              TV-Y7       22
# 2110             TV-14       49
# 348               TV-G       11
#
#                                                  genres production_countries  \
# 5458  ['family', 'action', 'animation', 'fantasy', '...               ['US']
# 2246           ['scifi', 'drama', 'fantasy', 'romance']               ['KR']
# 2449                       ['reality', 'documentation']               ['GB']
# 4929             ['documentation', 'crime', 'thriller']               ['US']
# 837                      ['thriller', 'drama', 'crime']               ['US']
# 5667                  ['action', 'animation', 'family']               ['US']
# 53                                 ['comedy', 'family']               ['US']
# 673   ['scifi', 'action', 'animation', 'comedy', 'fa...               ['US']
# 2110           ['documentation', 'history', 'european']               ['GB']
# 348       ['animation', 'family', 'comedy', 'european']         ['GB', 'ES']
#
#       seasons     imdb_id imdb_score imdb_votes  tmdb_popularity  tmdb_score
# 5458      2.0  tt15527308        6.3       86.0            5.800         8.2
# 2246      1.0   tt8487786        7.7     1015.0           19.741         8.1
# 2449      2.0   tt8092942        7.2     1097.0            6.250         8.0
# 4929      1.0  tt13651632        7.5    24892.0           15.428         7.4
# 837       9.0   tt2741602        8.0   242640.0          227.557         7.6
# 5667      1.0  tt18274176        7.8       33.0            2.104         7.0
# 53        4.0   tt0096643        6.5     2922.0            9.849         6.5
# 673       4.0   tt2139371        6.4      925.0            9.697         8.2
# 2110      1.0   tt6596634        7.3     1574.0            4.357         7.4
# 348       4.0   tt0487849        3.9       93.0           27.339         7.1

# %%
# bar plot of seasons and run time
bar=df['seasons'].value_counts()

# %%
bar[:10]
# Out:
# 1.0     1221
# 2.0      389
# 3.0      187
# 4.0      120
# 5.0       79
# 6.0       36
# 7.0       18
# 8.0       11
# 9.0        9
# 11.0       8
# 10.0       6
# Name: seasons, dtype: int64

# %%
bar[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.describe("")
# Out:
#        release_year      runtime      seasons  tmdb_popularity   tmdb_score
# count   2106.000000  2106.000000  2106.000000      2077.000000  1990.000000
# mean    2017.387939    38.978158     2.162868        26.756694     7.480413
# std        5.381505    17.626354     2.689041        87.589718     1.099177
# min     1945.000000     0.000000     1.000000         0.600000     0.500000
# 50%     2019.000000    41.000000     1.000000         8.413000     7.500000
# max     2022.000000   190.000000    42.000000      2226.231000    10.000000
